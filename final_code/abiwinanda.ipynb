# %%
import os
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import h5py
import cv2
# %matplotlib inline

# %%
labels = []

# %%
filename = None

for filename in range(1, 3065):
    with h5py.File('./brain_tumor_dataset/imageData/{}.mat'.format(filename), 'r') as f:
        label = f['cjdata']['label'][0][0] - 1
        labels.append(int(label))

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Conv2D , MaxPooling2D, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

# %%
inputs = Input(shape = (64, 64, 1))
conv1 =  Conv2D(32, (3,3), activation = 'relu', input_shape = [64, 64, 1])(inputs)
pool1 = MaxPooling2D(2)(conv1)
conv2 = Conv2D(32,(3,3), activation = 'relu')(pool1)
pool2 = MaxPooling2D(2)(conv2)
flatten = Flatten()(pool2)
dense1 = Dense(64, activation = 'relu')(flatten)
outputs = Dense(3, activation = 'softmax')(dense1)
model = Model(inputs=inputs, outputs=outputs)


model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 62, 62, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                401472
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 411,235
# Trainable params: 411,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i in range(len(labels)):
    if(labels[i]==0):
        labels[i] = "glioma"
    elif(labels[i]==1):
        labels[i] = "meningioma"
    else:
        labels[i] = "pituitary"

# %%
def importing_data(path):
    sample = []
    for filename in os.listdir(path):
        if "jpg" in filename:
            sample.append(filename)
    return sample

# %%
path = './brain_tumor_dataset/bt_images/'
train = importing_data(path)

train_data = pd.DataFrame({'image':train, 'label': labels})

# %%
from sklearn.model_selection import train_test_split
X_train, X_val = train_test_split(train_data, test_size = 0.1, shuffle = True, random_state = 42)

# %%
IMG_SIZE = 64
size = (IMG_SIZE,IMG_SIZE)

# %%
datagen = ImageDataGenerator(rescale = 1./255)

train_set = datagen.flow_from_dataframe(X_train,
                                        directory = './brain_tumor_dataset/bt_images/',
                                        x_col = 'image',
                                        y_col = 'label',
                                        target_size = size,
                                        color_mode = 'grayscale',
                                        class_mode = 'categorical',
                                        batch_size = 10,
                                        shuffle = True,
                                        interpolation = 'bilinear')

val_set = datagen.flow_from_dataframe(X_val,
                                      directory = './brain_tumor_dataset/bt_images/',
                                      x_col = 'image',
                                      y_col = 'label',
                                      target_size = size,
                                      color_mode = 'grayscale',
                                      class_mode = 'categorical',
                                      batch_size = 10,
                                      shuffle = True,
                                      interpolation = 'bilinear')

    

model.compile(optimizer = "Adam", loss='categorical_crossentropy', metrics =['acc'])  
es = EarlyStopping(monitor='val_loss', mode='min', patience=2, restore_best_weights=True, verbose=1)

checkpoint_cb = ModelCheckpoint("./models/abiwinanda.h5", save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 3, min_lr = 1e-5, mode = 'min', verbose=1)

history = model.fit(train_set, validation_data = val_set, epochs= 50, batch_size = 10, callbacks=[es, checkpoint_cb, reduce_lr])

# %%
def preprocess(img):
    img = img.astype(np.float32)
    img /= 255.0
    img = np.expand_dims(img,0)
    return img

# %%
val = X_val["image"].values.tolist()

# %%
class_names = {0: "glioma", 1: "meningoma", 2:"pituitary"}
d = 3
iters = 600
popsize = 10
model_path = "./models/abiwinanda.h5"

# %%
import keras 
keras_model = keras.models.load_model(model_path)
keras_model.compile(optimizer = "Adam", loss='categorical_crossentropy', metrics =['acc'])

# %%
def perturb(x):
    adv_img = orig.copy()

    pixs = np.array(np.split(x, len(x)/3)).astype(int)
    loc = (pixs[:, 0], pixs[:,1])
    val = pixs[:, 2]
    adv_img[loc] = val
    adv_img = np.expand_dims(adv_img,0)
    return adv_img

# %%
def optimize(x):
    adv_img = perturb(x)

    prob = keras_model.predict(preprocess(adv_img[0]))
    pred_orig = np.argmax(prob_orig)

    return prob[0][pred_orig]

# %%
pred_adv = 0
prob_adv = 0
ct = 0
def callback(x, convergence):
    global pred_adv, prob_adv, ct
    adv_img = perturb(x)


    prob = keras_model.predict(preprocess(adv_img[0]))

    pred_adv = np.argmax(prob)
    prob_adv = prob[0][pred_adv]
    if pred_adv != pred_orig:
        ct = ct+1
        return True

# %%
from scipy.optimize import differential_evolution

for filename in val:
    pred_adv = 0
    prob_adv = 0
    orig = cv2.imread(os.path.join("./brain_tumor_dataset/bt_images/",filename))
    orig = cv2.cvtColor(orig, cv2.COLOR_BGR2GRAY)
    orig = cv2.resize(orig, size)
    
    img = orig.copy()
    img = img.reshape(64,64,1)
    img = np.expand_dims(img,0)
    shape = img.shape
    
    
    prob_orig = keras_model.predict(preprocess(img[0]))
    pred_orig = np.argmax(prob_orig)

    bounds = [(0, shape[1]-1), (0, shape[2]-1), (0, 255)] * d
    result = differential_evolution(optimize, bounds, maxiter=iters, popsize=popsize, tol=1e-5, callback=callback)

    adv_img = perturb(result.x)

    prob = keras_model.predict(preprocess(adv_img[0]))
    print('Prob [%s]: %f --> Prob[%s]: %f ' %(class_names[pred_orig], prob_orig[0][pred_orig], class_names[pred_adv], prob_adv))

    if(pred_orig != pred_adv):
        cv2.imwrite('./outputs/'+ filename, adv_img[0])
# Out:
# Prob [pituitary]: 0.993369 --> Prob[pituitary]: 0.943707
# Prob [glioma]: 0.953879 --> Prob[glioma]: 0.634042
# Prob [pituitary]: 0.997594 --> Prob[pituitary]: 0.904879
# Prob [pituitary]: 0.997377 --> Prob[pituitary]: 0.984622
# Prob [meningoma]: 0.546422 --> Prob[pituitary]: 0.738574
# Prob [glioma]: 0.999829 --> Prob[glioma]: 0.997784
# Prob [meningoma]: 0.999976 --> Prob[meningoma]: 0.999959
# Prob [pituitary]: 0.959425 --> Prob[pituitary]: 0.663671
# Prob [glioma]: 0.999224 --> Prob[glioma]: 0.997691
# Prob [pituitary]: 0.991699 --> Prob[pituitary]: 0.932326
# Prob [meningoma]: 0.940403 --> Prob[meningoma]: 0.667465
# Prob [meningoma]: 0.999993 --> Prob[meningoma]: 0.999981
# Prob [glioma]: 0.999685 --> Prob[glioma]: 0.997041
# Prob [pituitary]: 0.992432 --> Prob[pituitary]: 0.683080
# Prob [pituitary]: 0.996604 --> Prob[pituitary]: 0.986183
# Prob [meningoma]: 0.999250 --> Prob[meningoma]: 0.986398
# Prob [meningoma]: 0.999862 --> Prob[meningoma]: 0.998439
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999998
# Prob [pituitary]: 0.991724 --> Prob[pituitary]: 0.933162
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999996
# Prob [pituitary]: 0.769441 --> Prob[glioma]: 0.671398
# Prob [meningoma]: 0.395978 --> Prob[pituitary]: 0.395236
# Prob [meningoma]: 0.982627 --> Prob[meningoma]: 0.864415
# Prob [pituitary]: 0.998783 --> Prob[pituitary]: 0.983812
# Prob [meningoma]: 0.999973 --> Prob[meningoma]: 0.999955
# Prob [meningoma]: 0.906855 --> Prob[pituitary]: 0.525582
# Prob [pituitary]: 0.998416 --> Prob[pituitary]: 0.982519
# Prob [meningoma]: 0.914829 --> Prob[glioma]: 0.517625
# Prob [meningoma]: 0.999925 --> Prob[meningoma]: 0.999062
# Prob [glioma]: 0.995565 --> Prob[glioma]: 0.967359
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [pituitary]: 0.995723 --> Prob[pituitary]: 0.951165
# Prob [meningoma]: 0.989890 --> Prob[meningoma]: 0.880119
# Prob [pituitary]: 0.944134 --> Prob[glioma]: 0.447598
# Prob [pituitary]: 0.944993 --> Prob[glioma]: 0.524462
# Prob [pituitary]: 0.941675 --> Prob[pituitary]: 0.534546
# Prob [glioma]: 0.997973 --> Prob[glioma]: 0.979522
# Prob [glioma]: 0.749578 --> Prob[glioma]: 0.502754
# Prob [pituitary]: 0.943778 --> Prob[pituitary]: 0.753794
# Prob [meningoma]: 0.941572 --> Prob[meningoma]: 0.715913
# Prob [pituitary]: 0.634474 --> Prob[meningoma]: 0.627245
# Prob [pituitary]: 0.977925 --> Prob[pituitary]: 0.828559
# Prob [glioma]: 0.999921 --> Prob[glioma]: 0.999353
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.933985 --> Prob[meningoma]: 0.657003
# Prob [glioma]: 0.743218 --> Prob[meningoma]: 0.711731
# Prob [pituitary]: 0.979139 --> Prob[glioma]: 0.542240
# Prob [pituitary]: 0.682565 --> Prob[meningoma]: 0.507102
# Prob [glioma]: 0.999630 --> Prob[glioma]: 0.996923
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [pituitary]: 0.810715 --> Prob[glioma]: 0.742742
# Prob [meningoma]: 0.999896 --> Prob[meningoma]: 0.999133
# Prob [pituitary]: 0.951920 --> Prob[pituitary]: 0.659138
# Prob [glioma]: 0.977479 --> Prob[glioma]: 0.908525
# Prob [glioma]: 0.999914 --> Prob[glioma]: 0.999399
# Prob [meningoma]: 0.760328 --> Prob[glioma]: 0.569364
# Prob [glioma]: 0.999688 --> Prob[glioma]: 0.997824
# Prob [meningoma]: 0.953247 --> Prob[meningoma]: 0.712265
# Prob [meningoma]: 0.981647 --> Prob[meningoma]: 0.865824
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999992 --> Prob[meningoma]: 0.999966
# Prob [glioma]: 0.945210 --> Prob[glioma]: 0.520202
# Prob [pituitary]: 0.999566 --> Prob[pituitary]: 0.982991
# Prob [glioma]: 0.801385 --> Prob[meningoma]: 0.617422
# Prob [pituitary]: 0.631794 --> Prob[glioma]: 0.496511
# Prob [glioma]: 0.989323 --> Prob[glioma]: 0.833007
# Prob [glioma]: 0.968376 --> Prob[glioma]: 0.868169
# Prob [meningoma]: 0.998894 --> Prob[meningoma]: 0.986539
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999997
# Prob [glioma]: 0.999543 --> Prob[glioma]: 0.998859
# Prob [pituitary]: 0.996593 --> Prob[pituitary]: 0.985013
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.725098 --> Prob[meningoma]: 0.561777
# Prob [pituitary]: 0.987135 --> Prob[pituitary]: 0.894113
# Prob [pituitary]: 0.980565 --> Prob[pituitary]: 0.579881
# Prob [pituitary]: 0.516146 --> Prob[meningoma]: 0.607741
# Prob [glioma]: 0.993556 --> Prob[glioma]: 0.940463
# Prob [glioma]: 0.759667 --> Prob[meningoma]: 0.557930
# Prob [glioma]: 0.996864 --> Prob[glioma]: 0.990445
# Prob [pituitary]: 0.998982 --> Prob[pituitary]: 0.960252
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.999478 --> Prob[glioma]: 0.994443
# Prob [meningoma]: 0.944500 --> Prob[meningoma]: 0.775869
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999998
# Prob [glioma]: 0.997240 --> Prob[glioma]: 0.991862
# Prob [meningoma]: 0.998233 --> Prob[meningoma]: 0.973463
# Prob [glioma]: 0.999821 --> Prob[glioma]: 0.997805
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.999570 --> Prob[glioma]: 0.998396
# Prob [pituitary]: 0.995534 --> Prob[pituitary]: 0.967305
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [pituitary]: 0.986500 --> Prob[pituitary]: 0.891400
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [meningoma]: 0.999908 --> Prob[meningoma]: 0.999654
# Prob [meningoma]: 0.999987 --> Prob[meningoma]: 0.999968
# Prob [glioma]: 0.998144 --> Prob[glioma]: 0.994555
# Prob [glioma]: 0.999619 --> Prob[glioma]: 0.998664
# Prob [glioma]: 0.999884 --> Prob[glioma]: 0.999004
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999998
# Prob [glioma]: 0.922947 --> Prob[meningoma]: 0.529216
# Prob [pituitary]: 0.999800 --> Prob[pituitary]: 0.999015
# Prob [glioma]: 0.998483 --> Prob[glioma]: 0.991522
# Prob [glioma]: 0.997333 --> Prob[glioma]: 0.969384
# Prob [meningoma]: 0.999821 --> Prob[meningoma]: 0.998208
# Prob [meningoma]: 0.996925 --> Prob[meningoma]: 0.983900
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [meningoma]: 0.998327 --> Prob[meningoma]: 0.963053
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999901 --> Prob[meningoma]: 0.999537
# Prob [pituitary]: 0.543249 --> Prob[glioma]: 0.628360
# Prob [pituitary]: 0.899949 --> Prob[pituitary]: 0.522585
# Prob [meningoma]: 0.601159 --> Prob[glioma]: 0.528620
# Prob [glioma]: 0.442484 --> Prob[meningoma]: 0.519602
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999998
# Prob [pituitary]: 0.848562 --> Prob[glioma]: 0.695836
# Prob [meningoma]: 0.839396 --> Prob[meningoma]: 0.622484
# Prob [meningoma]: 0.999991 --> Prob[meningoma]: 0.999856
# Prob [pituitary]: 0.942460 --> Prob[glioma]: 0.524535
# Prob [meningoma]: 0.999988 --> Prob[meningoma]: 0.999971
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [pituitary]: 0.969034 --> Prob[pituitary]: 0.572810
# Prob [glioma]: 0.999952 --> Prob[glioma]: 0.999686
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.977220 --> Prob[glioma]: 0.791188
# Prob [glioma]: 0.892293 --> Prob[meningoma]: 0.507930
# Prob [meningoma]: 0.818508 --> Prob[glioma]: 0.489224
# Prob [glioma]: 0.984173 --> Prob[glioma]: 0.867014
# Prob [glioma]: 0.999502 --> Prob[glioma]: 0.997813
# Prob [meningoma]: 0.841224 --> Prob[glioma]: 0.601735
# Prob [glioma]: 0.999139 --> Prob[glioma]: 0.975129
# Prob [glioma]: 0.774850 --> Prob[meningoma]: 0.611505
# Prob [glioma]: 0.977283 --> Prob[glioma]: 0.939959
# Prob [meningoma]: 0.777410 --> Prob[glioma]: 0.508748
# Prob [meningoma]: 0.999988 --> Prob[meningoma]: 0.999893
# Prob [meningoma]: 0.986130 --> Prob[meningoma]: 0.901644
# Prob [pituitary]: 0.667798 --> Prob[meningoma]: 0.546552
# Prob [pituitary]: 0.998804 --> Prob[pituitary]: 0.992368
# Prob [glioma]: 0.997677 --> Prob[glioma]: 0.980030
# Prob [meningoma]: 0.995298 --> Prob[meningoma]: 0.834813
# Prob [meningoma]: 0.999986 --> Prob[meningoma]: 0.999972
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999994
# Prob [glioma]: 0.999211 --> Prob[glioma]: 0.995258
# Prob [meningoma]: 0.998708 --> Prob[meningoma]: 0.992438
# Prob [pituitary]: 0.993673 --> Prob[pituitary]: 0.854917
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999757 --> Prob[meningoma]: 0.998621
# Prob [pituitary]: 0.927992 --> Prob[glioma]: 0.512390
# Prob [meningoma]: 0.982540 --> Prob[meningoma]: 0.869043
# Prob [meningoma]: 0.523526 --> Prob[pituitary]: 0.706950
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.985665 --> Prob[meningoma]: 0.905643
# Prob [pituitary]: 0.968168 --> Prob[pituitary]: 0.669924
# Prob [pituitary]: 0.966583 --> Prob[pituitary]: 0.722290
# Prob [pituitary]: 0.996189 --> Prob[pituitary]: 0.934092
# Prob [pituitary]: 0.728881 --> Prob[meningoma]: 0.670612
# Prob [glioma]: 0.997844 --> Prob[glioma]: 0.975274
# Prob [meningoma]: 0.984902 --> Prob[meningoma]: 0.704732
# Prob [glioma]: 0.884958 --> Prob[glioma]: 0.513919
# Prob [pituitary]: 0.996393 --> Prob[pituitary]: 0.972155
# Prob [meningoma]: 0.999291 --> Prob[meningoma]: 0.994595
# Prob [glioma]: 0.962434 --> Prob[glioma]: 0.875845
# Prob [pituitary]: 0.997432 --> Prob[pituitary]: 0.986130
# Prob [glioma]: 0.706567 --> Prob[meningoma]: 0.487326
# Prob [meningoma]: 0.998540 --> Prob[meningoma]: 0.980735
# Prob [meningoma]: 0.993986 --> Prob[meningoma]: 0.972610
# Prob [meningoma]: 0.998886 --> Prob[meningoma]: 0.990014
# Prob [pituitary]: 0.993109 --> Prob[pituitary]: 0.974595
# Prob [pituitary]: 0.854942 --> Prob[meningoma]: 0.524700
# Prob [meningoma]: 0.583138 --> Prob[glioma]: 0.619762
# Prob [meningoma]: 0.999988 --> Prob[meningoma]: 0.999977
# Prob [pituitary]: 0.997003 --> Prob[pituitary]: 0.921505
# Prob [pituitary]: 0.925987 --> Prob[pituitary]: 0.629437
# Prob [pituitary]: 0.998546 --> Prob[pituitary]: 0.974594
# Prob [glioma]: 0.840692 --> Prob[pituitary]: 0.668666
# Prob [pituitary]: 0.796155 --> Prob[glioma]: 0.568676
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.988550 --> Prob[glioma]: 0.778943
# Prob [meningoma]: 0.999994 --> Prob[meningoma]: 0.999989
# Prob [meningoma]: 0.999960 --> Prob[meningoma]: 0.999851
# Prob [glioma]: 0.688216 --> Prob[meningoma]: 0.509145
# Prob [meningoma]: 0.935636 --> Prob[meningoma]: 0.687740
# Prob [pituitary]: 0.875501 --> Prob[meningoma]: 0.505897
# Prob [meningoma]: 0.999567 --> Prob[meningoma]: 0.993212
# Prob [glioma]: 0.790572 --> Prob[meningoma]: 0.566276
# Prob [meningoma]: 0.994243 --> Prob[meningoma]: 0.953992
# Prob [meningoma]: 0.955068 --> Prob[meningoma]: 0.647406
# Prob [meningoma]: 0.643020 --> Prob[pituitary]: 0.568841
# Prob [glioma]: 0.720295 --> Prob[meningoma]: 0.499080
# Prob [meningoma]: 0.694069 --> Prob[glioma]: 0.637379
# Prob [pituitary]: 0.998889 --> Prob[pituitary]: 0.994438
# Prob [glioma]: 0.994364 --> Prob[glioma]: 0.959557
# Prob [meningoma]: 0.997059 --> Prob[meningoma]: 0.975069
# Prob [pituitary]: 0.999585 --> Prob[pituitary]: 0.986471
# Prob [pituitary]: 0.988148 --> Prob[pituitary]: 0.851396
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.906062 --> Prob[meningoma]: 0.691068
# Prob [meningoma]: 0.999242 --> Prob[meningoma]: 0.995981
# Prob [meningoma]: 0.862478 --> Prob[glioma]: 0.589208
# Prob [glioma]: 0.997290 --> Prob[glioma]: 0.987580
# Prob [pituitary]: 0.967148 --> Prob[pituitary]: 0.761799
# Prob [meningoma]: 0.690153 --> Prob[pituitary]: 0.597360
# Prob [glioma]: 0.998817 --> Prob[glioma]: 0.996247
# Prob [glioma]: 0.999926 --> Prob[glioma]: 0.999506
# Prob [meningoma]: 0.852097 --> Prob[glioma]: 0.424728
# Prob [pituitary]: 0.999273 --> Prob[pituitary]: 0.996553
# Prob [meningoma]: 0.999997 --> Prob[meningoma]: 0.999993
# Prob [glioma]: 0.999881 --> Prob[glioma]: 0.999346
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [pituitary]: 0.518952 --> Prob[glioma]: 0.681467
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [pituitary]: 0.999421 --> Prob[pituitary]: 0.997423
# Prob [meningoma]: 0.629616 --> Prob[pituitary]: 0.656833
# Prob [pituitary]: 0.987852 --> Prob[pituitary]: 0.924382
# Prob [pituitary]: 0.998747 --> Prob[pituitary]: 0.991161
# Prob [pituitary]: 0.984165 --> Prob[pituitary]: 0.884306
# Prob [pituitary]: 0.993447 --> Prob[pituitary]: 0.866348
# Prob [pituitary]: 0.868842 --> Prob[meningoma]: 0.522525
# Prob [glioma]: 0.536308 --> Prob[pituitary]: 0.673408
# Prob [pituitary]: 0.915955 --> Prob[pituitary]: 0.738566
# Prob [glioma]: 0.999987 --> Prob[glioma]: 0.999955
# Prob [pituitary]: 0.989814 --> Prob[pituitary]: 0.914447
# Prob [meningoma]: 0.701880 --> Prob[pituitary]: 0.510525
# Prob [meningoma]: 0.999996 --> Prob[meningoma]: 0.999993
# Prob [meningoma]: 0.999152 --> Prob[meningoma]: 0.994946
# Prob [glioma]: 0.986313 --> Prob[glioma]: 0.746445
# Prob [meningoma]: 0.908358 --> Prob[pituitary]: 0.538264
# Prob [glioma]: 0.999999 --> Prob[glioma]: 0.999998
# Prob [glioma]: 0.997938 --> Prob[glioma]: 0.957860
# Prob [meningoma]: 0.998855 --> Prob[meningoma]: 0.993206
# Prob [glioma]: 0.999952 --> Prob[glioma]: 0.999751
# Prob [glioma]: 0.999999 --> Prob[glioma]: 0.999999
# Prob [glioma]: 0.652270 --> Prob[meningoma]: 0.695159
# Prob [pituitary]: 0.985493 --> Prob[pituitary]: 0.897898
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [meningoma]: 0.911410 --> Prob[meningoma]: 0.577578
# Prob [meningoma]: 0.935794 --> Prob[glioma]: 0.503754
# Prob [meningoma]: 0.996356 --> Prob[meningoma]: 0.963476
# Prob [glioma]: 0.996704 --> Prob[glioma]: 0.975762
# Prob [meningoma]: 0.985073 --> Prob[meningoma]: 0.924928
# Prob [pituitary]: 0.994339 --> Prob[pituitary]: 0.958477
# Prob [glioma]: 0.976935 --> Prob[glioma]: 0.760796
# Prob [meningoma]: 0.782384 --> Prob[pituitary]: 0.536604
# Prob [pituitary]: 0.887004 --> Prob[glioma]: 0.555883
# Prob [pituitary]: 0.993218 --> Prob[pituitary]: 0.790989
# Prob [glioma]: 0.998434 --> Prob[glioma]: 0.984191
# Prob [meningoma]: 0.999936 --> Prob[meningoma]: 0.998136
# Prob [pituitary]: 0.987095 --> Prob[pituitary]: 0.883742
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999999
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999994
# Prob [pituitary]: 0.984036 --> Prob[pituitary]: 0.882524
# Prob [glioma]: 0.990809 --> Prob[glioma]: 0.964347
# Prob [pituitary]: 0.960135 --> Prob[meningoma]: 0.590580
# Prob [glioma]: 0.999871 --> Prob[glioma]: 0.999324
# Prob [meningoma]: 0.992554 --> Prob[meningoma]: 0.952547
# Prob [glioma]: 0.996221 --> Prob[glioma]: 0.972531
# Prob [glioma]: 0.992025 --> Prob[glioma]: 0.976812
# Prob [meningoma]: 0.997369 --> Prob[meningoma]: 0.980372
# Prob [glioma]: 0.988749 --> Prob[glioma]: 0.906670
# Prob [meningoma]: 0.999998 --> Prob[meningoma]: 0.999995
# Prob [glioma]: 0.999937 --> Prob[glioma]: 0.999396
# Prob [meningoma]: 0.424948 --> Prob[glioma]: 0.666021
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999989 --> Prob[meningoma]: 0.999962
# Prob [pituitary]: 0.984196 --> Prob[pituitary]: 0.807400
# Prob [meningoma]: 0.999995 --> Prob[meningoma]: 0.999992
# Prob [glioma]: 0.999864 --> Prob[glioma]: 0.999146
# Prob [pituitary]: 0.818774 --> Prob[glioma]: 0.580865
# Prob [pituitary]: 0.984440 --> Prob[pituitary]: 0.846647
# Prob [meningoma]: 0.788974 --> Prob[pituitary]: 0.536433
# Prob [glioma]: 0.992523 --> Prob[glioma]: 0.967638
# Prob [pituitary]: 0.824536 --> Prob[meningoma]: 0.563604
# Prob [pituitary]: 0.999481 --> Prob[pituitary]: 0.992645
# Prob [glioma]: 0.981675 --> Prob[glioma]: 0.947359
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.901449 --> Prob[glioma]: 0.525437
# Prob [pituitary]: 0.995776 --> Prob[pituitary]: 0.905856
# Prob [glioma]: 0.981934 --> Prob[glioma]: 0.907362
# Prob [meningoma]: 0.999852 --> Prob[meningoma]: 0.998885
# Prob [pituitary]: 0.897574 --> Prob[pituitary]: 0.563275
# Prob [meningoma]: 0.999958 --> Prob[meningoma]: 0.999768
# Prob [meningoma]: 0.999997 --> Prob[meningoma]: 0.999990
# Prob [meningoma]: 0.572026 --> Prob[pituitary]: 0.678258
# Prob [pituitary]: 0.990243 --> Prob[pituitary]: 0.816932
# Prob [pituitary]: 0.991003 --> Prob[pituitary]: 0.943402
# Prob [meningoma]: 0.999997 --> Prob[meningoma]: 0.999993
# Prob [meningoma]: 0.997497 --> Prob[meningoma]: 0.989683
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.960592 --> Prob[glioma]: 0.610858
# Prob [meningoma]: 0.999747 --> Prob[meningoma]: 0.998056
# Prob [meningoma]: 0.999743 --> Prob[meningoma]: 0.998911
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999998
# Prob [pituitary]: 0.984014 --> Prob[pituitary]: 0.664439
# Prob [meningoma]: 0.969381 --> Prob[meningoma]: 0.825722
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.993392 --> Prob[glioma]: 0.899944
# Prob [meningoma]: 0.961969 --> Prob[meningoma]: 0.572638
# Prob [glioma]: 0.987772 --> Prob[glioma]: 0.884384
# Prob [pituitary]: 0.936293 --> Prob[pituitary]: 0.557460
# Prob [pituitary]: 0.916039 --> Prob[glioma]: 0.553922
# Prob [glioma]: 0.999942 --> Prob[glioma]: 0.999828
# Prob [glioma]: 0.950936 --> Prob[meningoma]: 0.539023
# Prob [pituitary]: 0.995805 --> Prob[pituitary]: 0.987836
# Prob [glioma]: 0.966663 --> Prob[glioma]: 0.873110
# Prob [glioma]: 0.656800 --> Prob[meningoma]: 0.479408

# %%
print(ct)
# Out:
# 67

# %%
datagen = ImageDataGenerator(rescale = 1./255)
adv_set = datagen.flow_from_dataframe(X_val,
                                      directory = './outputs/',
                                      x_col = 'image',
                                      y_col = 'label',
                                      target_size = size,
                                      color_mode = 'grayscale',
                                      class_mode = 'categorical',
                                      batch_size = 1,
                                      shuffle = True,
                                      interpolation = 'bilinear')
# Out:
# Found 67 validated image filenames belonging to 3 classes.
# D:\Softwares\anaconda\envs\tf-gpu\lib\site-packages\keras_preprocessing\image\dataframe_iterator.py:279: UserWarning: Found 240 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(

# %%
predict = keras_model.evaluate(adv_set)
# Out:
# 67/67 [==============================] - 40s 26ms/step - loss: 0.7689 - acc: 0.3582

# %%
path = './outputs/'
adv = importing_data(path)
adv_df = pd.DataFrame({'image':adv})
val_df = X_val[~X_val.image.isin(adv_df.image)]

# %%
val_set = datagen.flow_from_dataframe(val_df,
                                      directory = './brain_tumor_dataset/bt_images/',
                                      x_col = 'image',
                                      y_col = 'label',
                                      target_size = size,
                                      color_mode = 'grayscale',
                                      class_mode = 'categorical',
                                      batch_size = 10,
                                      shuffle = True,
                                      interpolation = 'bilinear')
# Out:
# Found 240 validated image filenames belonging to 3 classes.

# %%
predict = keras_model.evaluate(val_set)
# Out:
# 24/24 [==============================] - 3s 102ms/step - loss: 0.1983 - acc: 0.9458

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=2, restore_best_weights=True, verbose=1)

checkpoint_cb = ModelCheckpoint("./models/abiwinanda_adversarial.h5", save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 3, min_lr = 1e-5, mode = 'min', verbose=1)

history_adv = keras_model.fit(adv_set, validation_data = val_set, epochs= 50, batch_size = 10, callbacks=[es, checkpoint_cb, reduce_lr])

# %%
class_names = {0: "glioma", 1: "meningoma", 2:"pituitary"}
d = 1
iters = 600
popsize = 10
model_path = "./models/abiwinanda_adversarial.h5"

# %%
import keras 
keras_model = keras.models.load_model(model_path)
keras_model.compile(optimizer = "Adam", loss='categorical_crossentropy', metrics =['acc'])

# %%
from scipy.optimize import differential_evolution

for filename in val:
    pred_adv = 0
    prob_adv = 0
    orig = cv2.imread(os.path.join("./brain_tumor_dataset/bt_images/",filename))
    orig = cv2.cvtColor(orig, cv2.COLOR_BGR2GRAY)
    orig = cv2.resize(orig, size)
    
    img = orig.copy()
    img = img.reshape(64,64,1)
    img = np.expand_dims(img,0)
    shape = img.shape
    
    
    prob_orig = keras_model.predict(preprocess(img[0]))
    pred_orig = np.argmax(prob_orig)

    bounds = [(0, shape[1]-1), (0, shape[2]-1), (0, 255)] * d
    result = differential_evolution(optimize, bounds, maxiter=iters, popsize=popsize, tol=1e-5, callback=callback)

    adv_img = perturb(result.x)

    prob = keras_model.predict(preprocess(adv_img[0]))
    print('Prob [%s]: %f --> Prob[%s]: %f ' %(class_names[pred_orig], prob_orig[0][pred_orig], class_names[pred_adv], prob_adv))
# Out:
# Prob [pituitary]: 0.954144 --> Prob[pituitary]: 0.825594
# Prob [glioma]: 0.860344 --> Prob[meningoma]: 0.527857
# Prob [pituitary]: 0.992554 --> Prob[pituitary]: 0.966793
# Prob [pituitary]: 0.987573 --> Prob[pituitary]: 0.969629
# Prob [pituitary]: 0.840629 --> Prob[meningoma]: 0.668600
# Prob [glioma]: 0.998155 --> Prob[glioma]: 0.992669
# Prob [meningoma]: 0.987989 --> Prob[meningoma]: 0.965925
# Prob [pituitary]: 0.895624 --> Prob[pituitary]: 0.689340
# Prob [glioma]: 0.827091 --> Prob[glioma]: 0.659291
# Prob [pituitary]: 0.973637 --> Prob[pituitary]: 0.883462
# Prob [meningoma]: 0.994640 --> Prob[meningoma]: 0.982730
# Prob [meningoma]: 0.997744 --> Prob[meningoma]: 0.991588
# Prob [glioma]: 0.998323 --> Prob[glioma]: 0.992649
# Prob [pituitary]: 0.926151 --> Prob[pituitary]: 0.816158
# Prob [pituitary]: 0.660326 --> Prob[meningoma]: 0.502183
# Prob [meningoma]: 0.999340 --> Prob[meningoma]: 0.995403
# Prob [meningoma]: 0.999907 --> Prob[meningoma]: 0.999879
# Prob [meningoma]: 0.999989 --> Prob[meningoma]: 0.999984
# Prob [pituitary]: 0.937987 --> Prob[pituitary]: 0.798438
# Prob [meningoma]: 0.999944 --> Prob[meningoma]: 0.999586
# Prob [pituitary]: 0.965671 --> Prob[pituitary]: 0.899769
# Prob [meningoma]: 0.943683 --> Prob[meningoma]: 0.873971
# Prob [meningoma]: 0.948755 --> Prob[meningoma]: 0.796294
# Prob [pituitary]: 0.988853 --> Prob[pituitary]: 0.957533
# Prob [meningoma]: 0.992245 --> Prob[meningoma]: 0.956221
# Prob [meningoma]: 0.994992 --> Prob[meningoma]: 0.982696
# Prob [pituitary]: 0.976448 --> Prob[pituitary]: 0.892824
# Prob [meningoma]: 0.957066 --> Prob[meningoma]: 0.841247
# Prob [meningoma]: 0.999627 --> Prob[meningoma]: 0.998498
# Prob [glioma]: 0.803199 --> Prob[meningoma]: 0.603110
# Prob [meningoma]: 0.999914 --> Prob[meningoma]: 0.999455
# Prob [pituitary]: 0.980689 --> Prob[pituitary]: 0.921569
# Prob [meningoma]: 0.996672 --> Prob[meningoma]: 0.980712
# Prob [pituitary]: 0.955856 --> Prob[pituitary]: 0.852962
# Prob [pituitary]: 0.995098 --> Prob[pituitary]: 0.982128
# Prob [meningoma]: 0.766251 --> Prob[meningoma]: 0.537901
# Prob [glioma]: 0.942484 --> Prob[glioma]: 0.764353
# Prob [meningoma]: 0.981082 --> Prob[meningoma]: 0.886156
# Prob [pituitary]: 0.643528 --> Prob[meningoma]: 0.525719
# Prob [glioma]: 0.702170 --> Prob[meningoma]: 0.524721
# Prob [pituitary]: 0.928883 --> Prob[pituitary]: 0.783151
# Prob [pituitary]: 0.614958 --> Prob[meningoma]: 0.582035
# Prob [glioma]: 0.999581 --> Prob[glioma]: 0.998018
# Prob [meningoma]: 0.999965 --> Prob[meningoma]: 0.999833
# Prob [meningoma]: 0.895539 --> Prob[meningoma]: 0.677070
# Prob [meningoma]: 0.887757 --> Prob[meningoma]: 0.676109
# Prob [pituitary]: 0.991062 --> Prob[pituitary]: 0.976498
# Prob [pituitary]: 0.943636 --> Prob[pituitary]: 0.862705
# Prob [glioma]: 0.998037 --> Prob[glioma]: 0.989722
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999997
# Prob [pituitary]: 0.999618 --> Prob[pituitary]: 0.998615
# Prob [meningoma]: 0.999942 --> Prob[meningoma]: 0.999614
# Prob [pituitary]: 0.977974 --> Prob[pituitary]: 0.934219
# Prob [glioma]: 0.903012 --> Prob[glioma]: 0.706402
# Prob [glioma]: 0.998079 --> Prob[glioma]: 0.992756
# Prob [meningoma]: 0.979771 --> Prob[meningoma]: 0.912845
# Prob [glioma]: 0.999450 --> Prob[glioma]: 0.998045
# Prob [meningoma]: 0.847146 --> Prob[meningoma]: 0.566266
# Prob [meningoma]: 0.647429 --> Prob[glioma]: 0.551105
# Prob [meningoma]: 0.999996 --> Prob[meningoma]: 0.999992
# Prob [meningoma]: 0.999488 --> Prob[meningoma]: 0.996402
# Prob [glioma]: 0.509913 --> Prob[pituitary]: 0.697852
# Prob [pituitary]: 0.987557 --> Prob[pituitary]: 0.953418
# Prob [glioma]: 0.999041 --> Prob[glioma]: 0.996224
# Prob [pituitary]: 0.499161 --> Prob[meningoma]: 0.593664
# Prob [glioma]: 0.986359 --> Prob[glioma]: 0.924785
# Prob [meningoma]: 0.857767 --> Prob[meningoma]: 0.628433
# Prob [meningoma]: 0.910561 --> Prob[meningoma]: 0.677642
# Prob [meningoma]: 0.999838 --> Prob[meningoma]: 0.998918
# Prob [glioma]: 0.989629 --> Prob[glioma]: 0.954667
# Prob [pituitary]: 0.977551 --> Prob[pituitary]: 0.948083
# Prob [meningoma]: 0.999996 --> Prob[meningoma]: 0.999994
# Prob [meningoma]: 0.994038 --> Prob[meningoma]: 0.965832
# Prob [pituitary]: 0.478124 --> Prob[meningoma]: 0.354459
# Prob [pituitary]: 0.933881 --> Prob[pituitary]: 0.713158
# Prob [meningoma]: 0.999790 --> Prob[meningoma]: 0.998744
# Prob [glioma]: 0.997716 --> Prob[glioma]: 0.994850
# Prob [glioma]: 0.977574 --> Prob[glioma]: 0.864326
# Prob [meningoma]: 0.543775 --> Prob[glioma]: 0.630512
# Prob [pituitary]: 0.998124 --> Prob[pituitary]: 0.993896
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [glioma]: 0.999834 --> Prob[glioma]: 0.999269
# Prob [meningoma]: 0.985148 --> Prob[meningoma]: 0.944305
# Prob [meningoma]: 0.999968 --> Prob[meningoma]: 0.999747
# Prob [glioma]: 0.635923 --> Prob[meningoma]: 0.502420
# Prob [meningoma]: 0.951149 --> Prob[meningoma]: 0.812992
# Prob [glioma]: 0.999373 --> Prob[glioma]: 0.996504
# Prob [meningoma]: 0.999972 --> Prob[meningoma]: 0.999944
# Prob [glioma]: 0.996361 --> Prob[glioma]: 0.980565
# Prob [pituitary]: 0.681132 --> Prob[pituitary]: 0.479764
# Prob [meningoma]: 0.999955 --> Prob[meningoma]: 0.999928
# Prob [pituitary]: 0.914494 --> Prob[pituitary]: 0.652318
# Prob [meningoma]: 0.999624 --> Prob[meningoma]: 0.997642
# Prob [meningoma]: 0.999884 --> Prob[meningoma]: 0.999655
# Prob [meningoma]: 0.999369 --> Prob[meningoma]: 0.995041
# Prob [glioma]: 0.993860 --> Prob[glioma]: 0.987331
# Prob [glioma]: 0.998638 --> Prob[glioma]: 0.996649
# Prob [glioma]: 0.999688 --> Prob[glioma]: 0.998949
# Prob [meningoma]: 0.999385 --> Prob[meningoma]: 0.996854
# Prob [glioma]: 0.997665 --> Prob[glioma]: 0.990114
# Prob [pituitary]: 0.997743 --> Prob[pituitary]: 0.992269
# Prob [glioma]: 0.999118 --> Prob[glioma]: 0.997211
# Prob [glioma]: 0.963065 --> Prob[glioma]: 0.835326
# Prob [meningoma]: 0.998239 --> Prob[meningoma]: 0.991579
# Prob [meningoma]: 0.989568 --> Prob[meningoma]: 0.980485
# Prob [meningoma]: 0.999169 --> Prob[meningoma]: 0.994398
# Prob [meningoma]: 0.977357 --> Prob[meningoma]: 0.819406
# Prob [meningoma]: 0.999990 --> Prob[meningoma]: 0.999981
# Prob [meningoma]: 0.998537 --> Prob[meningoma]: 0.993967
# Prob [glioma]: 0.973239 --> Prob[glioma]: 0.849687
# Prob [meningoma]: 0.728360 --> Prob[meningoma]: 0.506574
# Prob [meningoma]: 0.956408 --> Prob[meningoma]: 0.856446
# Prob [glioma]: 0.765162 --> Prob[meningoma]: 0.540451
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999926 --> Prob[meningoma]: 0.998293
# Prob [pituitary]: 0.998192 --> Prob[pituitary]: 0.990538
# Prob [meningoma]: 0.949182 --> Prob[meningoma]: 0.738889
# Prob [meningoma]: 0.998531 --> Prob[meningoma]: 0.989032
# Prob [pituitary]: 0.993922 --> Prob[pituitary]: 0.967218
# Prob [meningoma]: 0.982444 --> Prob[meningoma]: 0.944263
# Prob [meningoma]: 0.999992 --> Prob[meningoma]: 0.999989
# Prob [meningoma]: 0.999982 --> Prob[meningoma]: 0.999971
# Prob [pituitary]: 0.988747 --> Prob[pituitary]: 0.830511
# Prob [glioma]: 0.999708 --> Prob[glioma]: 0.998791
# Prob [meningoma]: 0.999999 --> Prob[meningoma]: 0.999997
# Prob [glioma]: 0.973984 --> Prob[glioma]: 0.925375
# Prob [glioma]: 0.998018 --> Prob[glioma]: 0.994173
# Prob [meningoma]: 0.896472 --> Prob[meningoma]: 0.671900
# Prob [glioma]: 0.612182 --> Prob[meningoma]: 0.502053
# Prob [glioma]: 0.999272 --> Prob[glioma]: 0.998563
# Prob [meningoma]: 0.955230 --> Prob[meningoma]: 0.810161
# Prob [glioma]: 0.997337 --> Prob[glioma]: 0.978859
# Prob [glioma]: 0.982390 --> Prob[glioma]: 0.930050
# Prob [glioma]: 0.764235 --> Prob[meningoma]: 0.500539
# Prob [meningoma]: 0.992504 --> Prob[meningoma]: 0.961053
# Prob [meningoma]: 0.963650 --> Prob[meningoma]: 0.864502
# Prob [meningoma]: 0.977717 --> Prob[meningoma]: 0.920992
# Prob [pituitary]: 0.927371 --> Prob[pituitary]: 0.820181
# Prob [pituitary]: 0.971185 --> Prob[pituitary]: 0.904071
# Prob [glioma]: 0.976658 --> Prob[glioma]: 0.909060
# Prob [meningoma]: 0.981815 --> Prob[meningoma]: 0.937700
# Prob [meningoma]: 0.998240 --> Prob[meningoma]: 0.992231
# Prob [meningoma]: 0.999443 --> Prob[meningoma]: 0.996632
# Prob [glioma]: 0.990893 --> Prob[glioma]: 0.956123
# Prob [meningoma]: 0.581015 --> Prob[glioma]: 0.540779
# Prob [pituitary]: 0.954517 --> Prob[pituitary]: 0.799780
# Prob [meningoma]: 0.999774 --> Prob[meningoma]: 0.998700
# Prob [meningoma]: 0.999947 --> Prob[meningoma]: 0.999725
# Prob [pituitary]: 0.835095 --> Prob[pituitary]: 0.630596
# Prob [meningoma]: 0.921044 --> Prob[meningoma]: 0.715552
# Prob [pituitary]: 0.613560 --> Prob[meningoma]: 0.593313
# Prob [meningoma]: 0.999051 --> Prob[meningoma]: 0.992165
# Prob [meningoma]: 0.970721 --> Prob[meningoma]: 0.875269
# Prob [pituitary]: 0.726084 --> Prob[meningoma]: 0.503587
# Prob [pituitary]: 0.819475 --> Prob[pituitary]: 0.605439
# Prob [pituitary]: 0.994566 --> Prob[pituitary]: 0.983162
# Prob [pituitary]: 0.883765 --> Prob[pituitary]: 0.622293
# Prob [glioma]: 0.992179 --> Prob[glioma]: 0.969264
# Prob [meningoma]: 0.989445 --> Prob[meningoma]: 0.926158
# Prob [glioma]: 0.947137 --> Prob[glioma]: 0.750268
# Prob [pituitary]: 0.993931 --> Prob[pituitary]: 0.981699
# Prob [meningoma]: 0.893733 --> Prob[meningoma]: 0.705196
# Prob [meningoma]: 0.556289 --> Prob[glioma]: 0.525149
# Prob [pituitary]: 0.992303 --> Prob[pituitary]: 0.977551
# Prob [meningoma]: 0.935020 --> Prob[meningoma]: 0.872266
# Prob [meningoma]: 0.999668 --> Prob[meningoma]: 0.998331
# Prob [meningoma]: 0.974689 --> Prob[meningoma]: 0.882121
# Prob [meningoma]: 0.923632 --> Prob[meningoma]: 0.701727
# Prob [pituitary]: 0.945385 --> Prob[pituitary]: 0.900694
# Prob [meningoma]: 0.515890 --> Prob[pituitary]: 0.682783
# Prob [meningoma]: 0.884016 --> Prob[meningoma]: 0.638145
# Prob [meningoma]: 0.999994 --> Prob[meningoma]: 0.999989
# Prob [pituitary]: 0.957360 --> Prob[pituitary]: 0.875903
# Prob [pituitary]: 0.921912 --> Prob[pituitary]: 0.738067
# Prob [pituitary]: 0.991047 --> Prob[pituitary]: 0.970488
# Prob [pituitary]: 0.968544 --> Prob[pituitary]: 0.860596
# Prob [pituitary]: 0.878409 --> Prob[pituitary]: 0.668773
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.989225 --> Prob[glioma]: 0.943650
# Prob [meningoma]: 0.999702 --> Prob[meningoma]: 0.998798
# Prob [meningoma]: 0.999158 --> Prob[meningoma]: 0.996809
# Prob [glioma]: 0.996819 --> Prob[glioma]: 0.959085
# Prob [glioma]: 0.848268 --> Prob[glioma]: 0.608061
# Prob [pituitary]: 0.926880 --> Prob[pituitary]: 0.817911
# Prob [meningoma]: 0.999971 --> Prob[meningoma]: 0.999959
# Prob [meningoma]: 0.821439 --> Prob[glioma]: 0.509297
# Prob [meningoma]: 0.763419 --> Prob[glioma]: 0.517702
# Prob [meningoma]: 0.952688 --> Prob[meningoma]: 0.800550
# Prob [meningoma]: 0.980118 --> Prob[meningoma]: 0.895196
# Prob [meningoma]: 0.959967 --> Prob[meningoma]: 0.757581
# Prob [glioma]: 0.972493 --> Prob[glioma]: 0.890946
# Prob [pituitary]: 0.984036 --> Prob[pituitary]: 0.913933
# Prob [glioma]: 0.998740 --> Prob[glioma]: 0.995635
# Prob [meningoma]: 0.998748 --> Prob[meningoma]: 0.995298
# Prob [pituitary]: 0.999084 --> Prob[pituitary]: 0.997239
# Prob [pituitary]: 0.973586 --> Prob[pituitary]: 0.871327
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.880223 --> Prob[meningoma]: 0.693247
# Prob [meningoma]: 0.999325 --> Prob[meningoma]: 0.997945
# Prob [glioma]: 0.912397 --> Prob[glioma]: 0.658314
# Prob [glioma]: 0.935355 --> Prob[glioma]: 0.829611
# Prob [pituitary]: 0.826825 --> Prob[pituitary]: 0.568763
# Prob [meningoma]: 0.995594 --> Prob[meningoma]: 0.983627
# Prob [meningoma]: 0.509947 --> Prob[glioma]: 0.705113
# Prob [glioma]: 0.999168 --> Prob[glioma]: 0.997044
# Prob [meningoma]: 0.981790 --> Prob[meningoma]: 0.929714
# Prob [pituitary]: 0.997344 --> Prob[pituitary]: 0.991971
# Prob [meningoma]: 0.998096 --> Prob[meningoma]: 0.991225
# Prob [glioma]: 0.999969 --> Prob[glioma]: 0.999958
# Prob [meningoma]: 0.999977 --> Prob[meningoma]: 0.999950
# Prob [glioma]: 0.974277 --> Prob[glioma]: 0.882236
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [pituitary]: 0.934882 --> Prob[pituitary]: 0.840282
# Prob [meningoma]: 0.866560 --> Prob[meningoma]: 0.550032
# Prob [pituitary]: 0.964305 --> Prob[pituitary]: 0.905293
# Prob [pituitary]: 0.983168 --> Prob[pituitary]: 0.941130
# Prob [pituitary]: 0.502011 --> Prob[meningoma]: 0.566910
# Prob [pituitary]: 0.950398 --> Prob[pituitary]: 0.829234
# Prob [meningoma]: 0.854433 --> Prob[meningoma]: 0.622369
# Prob [pituitary]: 0.854144 --> Prob[pituitary]: 0.698641
# Prob [meningoma]: 0.974111 --> Prob[meningoma]: 0.920647
# Prob [glioma]: 0.999966 --> Prob[glioma]: 0.999953
# Prob [pituitary]: 0.905014 --> Prob[pituitary]: 0.639196
# Prob [meningoma]: 0.994616 --> Prob[meningoma]: 0.984607
# Prob [meningoma]: 0.998313 --> Prob[meningoma]: 0.992312
# Prob [meningoma]: 0.976575 --> Prob[meningoma]: 0.940218
# Prob [glioma]: 0.958911 --> Prob[glioma]: 0.723506
# Prob [meningoma]: 0.992900 --> Prob[meningoma]: 0.970798
# Prob [glioma]: 0.999989 --> Prob[glioma]: 0.999984
# Prob [glioma]: 0.996155 --> Prob[glioma]: 0.975376
# Prob [meningoma]: 0.994021 --> Prob[meningoma]: 0.975330
# Prob [glioma]: 0.999963 --> Prob[glioma]: 0.999954
# Prob [glioma]: 0.999979 --> Prob[glioma]: 0.999967
# Prob [meningoma]: 0.949480 --> Prob[meningoma]: 0.653143
# Prob [pituitary]: 0.943973 --> Prob[pituitary]: 0.866681
# Prob [meningoma]: 0.999942 --> Prob[meningoma]: 0.999764
# Prob [glioma]: 0.698832 --> Prob[meningoma]: 0.601800
# Prob [meningoma]: 0.989260 --> Prob[meningoma]: 0.941482
# Prob [meningoma]: 0.999601 --> Prob[meningoma]: 0.998264
# Prob [glioma]: 0.511166 --> Prob[meningoma]: 0.400272
# Prob [meningoma]: 0.941163 --> Prob[meningoma]: 0.820711
# Prob [pituitary]: 0.912084 --> Prob[pituitary]: 0.678020
# Prob [glioma]: 0.994698 --> Prob[glioma]: 0.970590
# Prob [meningoma]: 0.996508 --> Prob[meningoma]: 0.988807
# Prob [pituitary]: 0.950254 --> Prob[pituitary]: 0.786869
# Prob [pituitary]: 0.987776 --> Prob[pituitary]: 0.946595
# Prob [glioma]: 0.766052 --> Prob[meningoma]: 0.503552
# Prob [meningoma]: 0.999796 --> Prob[meningoma]: 0.999095
# Prob [pituitary]: 0.656375 --> Prob[meningoma]: 0.607129
# Prob [meningoma]: 0.999928 --> Prob[meningoma]: 0.999637
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [meningoma]: 0.999997 --> Prob[meningoma]: 0.999993
# Prob [pituitary]: 0.860500 --> Prob[pituitary]: 0.686482
# Prob [glioma]: 0.831988 --> Prob[glioma]: 0.560091
# Prob [pituitary]: 0.980424 --> Prob[pituitary]: 0.772023
# Prob [glioma]: 0.996018 --> Prob[glioma]: 0.986256
# Prob [meningoma]: 0.862192 --> Prob[meningoma]: 0.592687
# Prob [glioma]: 0.996784 --> Prob[glioma]: 0.991860
# Prob [glioma]: 0.789802 --> Prob[glioma]: 0.546357
# Prob [meningoma]: 0.805254 --> Prob[meningoma]: 0.570040
# Prob [glioma]: 0.960543 --> Prob[glioma]: 0.860162
# Prob [meningoma]: 0.999811 --> Prob[meningoma]: 0.999047
# Prob [glioma]: 0.999902 --> Prob[glioma]: 0.999723
# Prob [glioma]: 0.971977 --> Prob[glioma]: 0.841341
# Prob [meningoma]: 0.999974 --> Prob[meningoma]: 0.999775
# Prob [meningoma]: 0.999897 --> Prob[meningoma]: 0.999368
# Prob [pituitary]: 0.935717 --> Prob[pituitary]: 0.793972
# Prob [meningoma]: 0.999955 --> Prob[meningoma]: 0.999734
# Prob [glioma]: 0.936518 --> Prob[glioma]: 0.750922
# Prob [pituitary]: 0.925069 --> Prob[pituitary]: 0.724933
# Prob [meningoma]: 0.505409 --> Prob[pituitary]: 0.667204
# Prob [meningoma]: 0.993545 --> Prob[meningoma]: 0.976015
# Prob [glioma]: 0.830136 --> Prob[glioma]: 0.727814
# Prob [pituitary]: 0.906093 --> Prob[pituitary]: 0.756041
# Prob [pituitary]: 0.993819 --> Prob[pituitary]: 0.957209
# Prob [glioma]: 0.624223 --> Prob[meningoma]: 0.559312
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [meningoma]: 0.973883 --> Prob[meningoma]: 0.899537
# Prob [pituitary]: 0.891341 --> Prob[pituitary]: 0.674678
# Prob [meningoma]: 0.833343 --> Prob[meningoma]: 0.538683
# Prob [meningoma]: 0.998873 --> Prob[meningoma]: 0.995358
# Prob [meningoma]: 0.991353 --> Prob[meningoma]: 0.956492
# Prob [meningoma]: 0.999929 --> Prob[meningoma]: 0.999910
# Prob [meningoma]: 0.999880 --> Prob[meningoma]: 0.999541
# Prob [pituitary]: 0.639892 --> Prob[meningoma]: 0.559010
# Prob [pituitary]: 0.919041 --> Prob[pituitary]: 0.729361
# Prob [pituitary]: 0.901643 --> Prob[pituitary]: 0.757298
# Prob [meningoma]: 0.994537 --> Prob[meningoma]: 0.963500
# Prob [meningoma]: 0.756160 --> Prob[meningoma]: 0.572812
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 0.999999
# Prob [glioma]: 0.986013 --> Prob[glioma]: 0.940368
# Prob [meningoma]: 0.996990 --> Prob[meningoma]: 0.987746
# Prob [meningoma]: 0.999898 --> Prob[meningoma]: 0.999563
# Prob [meningoma]: 0.999540 --> Prob[meningoma]: 0.996462
# Prob [pituitary]: 0.992167 --> Prob[pituitary]: 0.915147
# Prob [meningoma]: 0.684012 --> Prob[glioma]: 0.503247
# Prob [meningoma]: 1.000000 --> Prob[meningoma]: 1.000000
# Prob [glioma]: 0.977176 --> Prob[glioma]: 0.905313
# Prob [meningoma]: 0.971067 --> Prob[meningoma]: 0.852010
# Prob [glioma]: 0.999122 --> Prob[glioma]: 0.997490
# Prob [pituitary]: 0.413600 --> Prob[glioma]: 0.495037
# Prob [pituitary]: 0.962098 --> Prob[pituitary]: 0.879936
# Prob [glioma]: 0.992115 --> Prob[glioma]: 0.976914
# Prob [glioma]: 0.997297 --> Prob[glioma]: 0.990635
# Prob [pituitary]: 0.983962 --> Prob[pituitary]: 0.969411
# Prob [meningoma]: 0.536106 --> Prob[glioma]: 0.605986
# Prob [meningoma]: 0.902503 --> Prob[glioma]: 0.637599

# %%
print(ct)
# Out:
# 36

# %%
path = './outputs/'
adv = importing_data(path)
adv_df = pd.DataFrame({'image':adv})
val = X_val[~X_val.image.isin(adv_df.image)]

# %%
val_set = datagen.flow_from_dataframe(val,
                                      directory = './brain_tumor_dataset/bt_images/',
                                      x_col = 'image',
                                      y_col = 'label',
                                      target_size = size,
                                      color_mode = 'grayscale',
                                      class_mode = 'categorical',
                                      batch_size = 10,
                                      shuffle = True,
                                      interpolation = 'bilinear')
predict = keras_model.evaluate(val_set)
# Out:
# Found 240 validated image filenames belonging to 3 classes.
# 24/24 [==============================] - 7s 262ms/step - loss: 0.1805 - acc: 0.9375

# %%
import math

def ssim(img1, img2):
    C1 = (0.01 * 255)**2
    C2 = (0.03 * 255)**2

    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    kernel = cv2.getGaussianKernel(11, 1.5)
    window = np.outer(kernel, kernel.transpose())

    mu1 = cv2.filter2D(img1, -1, window)[5:-5, 5:-5]  # valid
    mu2 = cv2.filter2D(img2, -1, window)[5:-5, 5:-5]
    mu1_sq = mu1**2
    mu2_sq = mu2**2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = cv2.filter2D(img1**2, -1, window)[5:-5, 5:-5] - mu1_sq
    sigma2_sq = cv2.filter2D(img2**2, -1, window)[5:-5, 5:-5] - mu2_sq
    sigma12 = cv2.filter2D(img1 * img2, -1, window)[5:-5, 5:-5] - mu1_mu2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) *
                                                            (sigma1_sq + sigma2_sq + C2))
    return ssim_map.mean()

def calculate_ssim(img1, img2):
    if not img1.shape == img2.shape:
        raise ValueError('Input images must have the same dimensions.')
    if img1.ndim == 2:
        return ssim(img1, img2)
    elif img1.ndim == 3:
        if img1.shape[2] == 1:
            return ssim(np.squeeze(img1), np.squeeze(img2))

# %%
calculate_ssim(adv_img[0], orig)
# Out:
# 0.9884681036584159

# %%
from scipy.optimize import differential_evolution
filename_orig = "./brain_tumor_dataset/bt_images/8.jpg"
filename_adv = "./outputs/46.jpg"
pred_adv = 0
prob_adv = 0

orig = cv2.imread(filename_orig)
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2GRAY)
orig = cv2.resize(orig, size)
img = orig.copy()
img = img.reshape(64,64,1)
img = np.expand_dims(img,0)
shape = img.shape
prob_orig = keras_model.predict(preprocess(img[0]))
pred_orig = np.argmax(prob_orig)

orig = cv2.imread(filename_adv)
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2GRAY)
orig = cv2.resize(orig, size)
img = orig.copy()
img = img.reshape(64,64,1)
img = np.expand_dims(img,0)
shape = img.shape
prob_adv = keras_model.predict(preprocess(img[0]))
pred_adv = np.argmax(prob_adv)

print('Prob [%s]: %f --> Prob[%s]: %f' %(class_names[pred_orig], prob_orig[0][pred_orig], class_names[pred_adv], prob_adv[0][pred_adv]))
# Out:
# Prob [glioma]: 0.972148 --> Prob[glioma]: 0.617895

# %%
pred_adv = 0
prob_adv = 0
d=5
orig = cv2.imread(os.path.join("./brain_tumor_dataset/bt_images/8.jpg"))
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2GRAY)
orig = cv2.resize(orig, size)

img = orig.copy()
img = img.reshape(64,64,1)
img = np.expand_dims(img,0)
shape = img.shape


prob_orig = keras_model.predict(preprocess(img[0]))
pred_orig = np.argmax(prob_orig)

bounds = [(0, shape[1]-1), (0, shape[2]-1), (0, 255)] * d
result = differential_evolution(optimize, bounds, maxiter=iters, popsize=popsize, tol=1e-5, callback=callback)

adv_img = perturb(result.x)

prob = keras_model.predict(preprocess(adv_img[0]))
print('Prob [%s]: %f --> Prob[%s]: %f ' %(class_names[pred_orig], prob_orig[0][pred_orig], class_names[pred_adv], prob_adv))
cv2.imwrite('./output/8_5.jpg', adv_img[0])
# Out:
# Prob [glioma]: 0.972148 --> Prob[meningoma]: 0.507021
# True
